# %%
import sqlite3
import pandas as pd

# 1. Connect to SQLite database
db_path = "/Users/usuario/Documents/GitHub/f1-race-analytics/data/Formula1.sqlite"  # Adjust filename if needed
conn = sqlite3.connect(db_path)

# 2. Query to inspect table names in SQLite
tables_df = pd.read_sql_query(
    "SELECT name FROM sqlite_master WHERE type='table';", conn
)
print("Database Tables:")
print(tables_df)

# 3. Close connection
conn.close()
# Out:
# Database Tables:
#                      name
# 0                circuits
# 1                   races
# 2        driver_standings
# 3                 drivers
# 4            constructors
# 5                 results
# 6   constructor_standings
# 7     constructor_results
# 8                laptimes
# 9                pitstops
# 10             qualifying
# 11                seasons
# 12                 status
